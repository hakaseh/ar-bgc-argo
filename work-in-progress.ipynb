# %% [markdown]
# # Work in progress

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### POC

# %%
par_poc = [
#[(12128*(470/700)**-0.78)/12.01,0.59/12.01,'V24 Cphyto'],
[(48811*(470/700)**-0.78)/12.01,24/12.01,'Vives24'],
[31200/12.01, 3/12.01, 'Haentjens17'],
[6368,-0.2,'Sukigara25'],
[35422/12.01,-14.4/12.01,'Cetinic12'],
[3963.45,-0.6,'Rembauville17'],
[37601/12.01,-4.95/12.01,'Schallenberg19'],
]

ran_bbp = np.arange(2,12)*10**-4
plt.figure()
for i in range(np.size(par_poc,0)):
    plt.plot(ran_bbp,ran_bbp*par_poc[i][0]+par_poc[i][1],label=par_poc[i][2])
plt.plot(ran_bbp,(1985.9*ran_bbp**0.5037)/12.01,label='Koestner22') #nonlinear mg m-3 Koestoner et al. 2024
plt.legend()
plt.xlabel('bbp700')
plt.ylabel('POC (mmol m-3)')
plt.axhline(0,color='k',ls='--')
